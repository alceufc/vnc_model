# %% [markdown]
# # VnC Model

# %%
# Jupyter configuration.
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Python general modules.
import sys
import os

# Import data mining modules.
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def vnc_upvotes(T, params):
    '''
    Returns an up-vote time-series generated by the VnC model.
    
    T is an array-like structure with time-stamps where VnC is evaluated.
    
    params is a dict with VnC's parameters.
    '''
